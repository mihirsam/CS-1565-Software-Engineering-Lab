# %%
studentDetails = {}
studentMarks = {}
studentAttendance = {}
studentRemarks = {}

teacherDetails = {}

# %%
def studentRegister():
    print("\nWELCOME TO STUDENT REGISTRATION\n")
    
    nam = input("Enter Your Name : ")
    sec = input("Enter Your Section : ")
    dep = input("Enter Your Department : ")
    reg = int(input("Enter Your Registration Number : "))
    pas = input("Enter Your Password : ")
    
    temp = []
    temp.append(nam)
    temp.append(sec)
    temp.append(dep)
    temp.append(reg)
    temp.append(pas)
 
    studentDetails[reg] = temp
    studentMarks[reg] = []
    studentAttendance[reg] = []
    studentRemarks[reg] = []
    
    print("\nSTUDENT REGISTRATION SUCCESSFUL\n")

# %%
def studentLogIn():
    print("\nWELCOME TO STUDENT PORTAL\n")
    
    reg = int(input("Enter The Registration Number : "))
    pas = input("Enter The Password : ")
    
    if reg in studentDetails.keys():
        if(studentDetails[reg][4] == pas):
            print("\nLog-In Successful\n")
            studentPortal(reg)
        else:
            print("\nWrong Password\n")
    else:
        while(True):
            choice = ("\nStudent Not Registered!\nDo You Want To Register ?\n1. Yes\n2. No\nChoice : ")
        
            if(choice == 1):
                studentRegister()
            elif(choice == 2):
                break
            else:
                print("Invalid Input!\nTry Again!")

# %%
def teacherRegister():
    print("\nWELCOME TO TEACHER REGISTRATION\n")
    
    nam = input("Enter Your Name : ")
    t_no = int(input("Enter Your Teacher Number : "))
    pas = input("Enter Your Password : ")
    
    temp = []
    temp.append(nam)
    temp.append(t_no)
    temp.append(pas)
    
    teacherDetails[t_no] = temp
    print("\nSTUDENT REGISTRATION SUCCESSFUL\n")

# %%
def teacherLogIn():
    print("\nWELCOME TO TEACHER PORTAL\n")
    
    t_no = int(input("Enter Teacher Number : "))
    pas = input("Enter Password : ")
    
    if t_no in teacherDetails.keys():
        if(teacherDetails[t_no][2] == pas):
            print("\nLog-In Successful!\n")
            teacherPortal(t_no)
            
        else:
            print("\nWrong Password!")
    else:
        while(True):
            choice = int(input("\nTeacher Not Registered!\nDo You Want To Register ?\n1. Yes\n2. No\nChoice : "))
        
            if(choice == 1):
                teacherRegister()
            elif(choice == 2):
                break
            else:
                print("\nInvalid Input!\nTry Again!")

# %%
def teacherPortal(t_no):
    print("\n\nWELCOME {} TO THE TEACHER PORTAL" .format(teacherDetails[t_no][0]))
    
    while(True):
        choice = int(input("\n1. Enter Student Marks\n2. Enter Student Attendance\n3. Enter Student Remarks\n4. Exit\nChoice : "))

        if(choice == 1):
            reg = int(input("Enter The Student Registartion Number : "))

            if reg in studentDetails.keys():
                sub = input("Enter The Subject : ")
                mar = int(input("Enter The Marks : "))

                studentMarks[reg].append(sub)
                studentMarks[reg].append(mar)

                print("\n\nMarks Has Been Updated!")

            else:
                print("Student Not Found!")

        elif(choice == 2):
            reg = int(input("Enter The Student Registartion Number : "))

            if reg in studentDetails.keys():
                sub = input("Enter The Subject : ")
                att = int(input("Enter The Attendance : "))

                studentAttendance[reg].append(sub)
                studentAttendance[reg].append(att)

                print("\n\nAttendance Has Been Updated!")

            else:
                print("Student Not Found!")


        elif(choice == 3):
            reg = int(input("Enter The Student Registartion Number : "))

            if reg in studentDetails.keys():
                rem = input("Enter The Remarks : ")
                
                studentRemarks[reg].append(teacherDetails[t_no][0])
                studentRemarks[reg].append(rem)

                print("\n\nRemarks Has Been Updated!")

            else:
                print("Student Not Found!")

                
        elif(choice == 4):
            print("\nBye Bye!")
            break
            
        else:
            print("\nInvalid Input!\nTry Again!")

# %%
def studentPortal(reg):
        print("\n\nWELCOME {} TO THE STUDENT PORTAL" .format(studentDetails[reg][0]))
        
        while(True):
            choice = int(input("1. Check Marks\n2. Check Attendance\n3. Check Remarks\n4. Exit\nChoice : "))
            
            if(choice == 1):
                print("\n\tSUBJECT\tMARKS\n")
                for i in range(0, int((len(studentMarks[reg])/2))):
                    print(studentMarks[2*i],"\t",studentMarks[2*i + 1])

            elif(choice == 2):
                print("\n\tSUBJECT\tATTENDANCE\n")
                for i in range(0, int((len(studentAttendance[reg])/2))):
                    print(studentAttendance[2*i],"\t",studentAttendance[2*i + 1])

            elif(choice == 3):
                print("\n\tTEACHER\tREMARKS\n")
                for i in range(0, int((len(studentRemarks[reg])/2))):
                    print(studentRemarks[2*i],"\t",studentRemarks[2*i + 1])
            
            elif(choice == 4):
                print("\nBye Bye!")
                break
                
            else:
                print("\nInvalid Input")

# %%
while(True):
    choice = int(input("\n\nWELCOME TO SMIT\n1. Student Portal\n2. Teacher Portal\n3. Exit\nChoice : "))
    
    if(choice == 1):
        
        while(True):
            choice_student = int(input("\n1. Student Registration\n2. Student Log-In\n3. Back\nChoice : "))

            if(choice_student == 1):
                studentRegister()
            elif(choice_student == 2):
                studentLogIn()
            elif(choice_student == 3):
                break
            else:
                print("\nInvalid Input!\nTry Again!")
        
    elif(choice == 2):
        
        while(True):
            choice_teacher = int(input("\n1. Teacher Registration\n2. Teacher Log-In\n3. Back\nChoice : "))

            if(choice_teacher == 1):
                teacherRegister()
            elif(choice_teacher == 2):
                teacherLogIn()
            elif(choice_teacher == 3):
                break
            else:
                print("\nInvalid Input!\nTry Again!")
                
    elif(choice == 3):
        print("\nBye Bye!")
        exit()
# Out:
# WELCOME TO SMIT
# 1. Student Portal
# 2. Teacher Portal
# 3. Exit
# Choice : 1
#
# 1. Student Registration
# 2. Student Log-In
# 3. Back
# Choice : 1
#
# WELCOME TO STUDENT REGISTRATION
#
# Enter Your Name : Mihir
# Enter Your Section : A
# Enter Your Department : CSE
# Enter Your Registration Number : 201600045
# Enter Your Password : qwe123
#
# STUDENT REGISTRATION SUCCESSFUL
#
#
# 1. Student Registration
# 2. Student Log-In
# 3. Back
# Choice : 3
#
#
# WELCOME TO SMIT
# 1. Student Portal
# 2. Teacher Portal
# 3. Exit
# Choice : 2
#
# 1. Teacher Registration
# 2. Teacher Log-In
# 3. Back
# Choice : 1
#
# WELCOME TO TEACHER REGISTRATION
#
# Enter Your Name : Suraj
# Enter Your Teacher Number : 123
# Enter Your Password : qwe123
#
# STUDENT REGISTRATION SUCCESSFUL
#
#
# 1. Teacher Registration
# 2. Teacher Log-In
# 3. Back
# Choice : 2
#
# WELCOME TO TEACHER PORTAL
#
# Enter Teacher Number : 123
# Enter Password : qwe123
#
# Log-In Successful!
#
#
#
# WELCOME Suraj TO THE TEACHER PORTAL
#
# 1. Enter Student Marks
# 2. Enter Student Attendance
# 3. Enter Student Remarks
# 4. Exit
# Choice : 1
# Enter The Student Registartion Number : 201600045
# Enter The Subject : Maths
# Enter The Marks : 98
#
#
# Marks Has Been Updated!
#
# 1. Enter Student Marks
# 2. Enter Student Attendance
# 3. Enter Student Remarks
# 4. Exit
# Choice : 2
# Enter The Student Registartion Number : 201600045
# Enter The Subject : Maths
# Enter The Attendance : 90
#
#
# Attendance Has Been Updated!
#
# 1. Enter Student Marks
# 2. Enter Student Attendance
# 3. Enter Student Remarks
# 4. Exit
# Choice : 3
# Enter The Student Registartion Number : 201600045
# Enter The Remarks : very good boy
#
#
# Remarks Has Been Updated!
#
# 1. Enter Student Marks
# 2. Enter Student Attendance
# 3. Enter Student Remarks
# 4. Exit
# Choice : 4
#
# Bye Bye!
#
# 1. Teacher Registration
# 2. Teacher Log-In
# 3. Back
# Choice : 3
#
#
# WELCOME TO SMIT
# 1. Student Portal
# 2. Teacher Portal
# 3. Exit
# Choice : 1
#
# 1. Student Registration
# 2. Student Log-In
# 3. Back
# Choice : 2
#
# WELCOME TO STUDENT PORTAL
#
# Enter The Registration Number : 201600045
# Enter The Password : qwe123
#
# Log-In Successful
#
#
#
# WELCOME Mihir TO THE STUDENT PORTAL
# 1. Check Marks
# 2. Check Attendance
# 3. Check Remarks
# 4. Exit
# Choice : 1
#
# 	SUBJECT	MARKS
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-0ac429feaa49> in <module>()
#      10                 studentRegister()
#      11             elif(choice_student == 2):
# ---> 12                 studentLogIn()
#      13             elif(choice_student == 3):
#      14                 break
#
# <ipython-input-19-cc1887eb07b4> in studentLogIn()
#       8         if(studentDetails[reg][4] == pas):
#       9             print("\nLog-In Successful\n")
# ---> 10             studentPortal(reg)
#      11         else:
#      12             print("\nWrong Password\n")
#
# <ipython-input-40-97088b2a6892> in studentPortal(reg)
#       8                 print("\n\tSUBJECT\tMARKS\n")
#       9                 for i in range(0, int((len(studentMarks[reg])/2))):
# ---> 10                     print(studentMarks[2*i],"\t",studentMarks[2*i + 1])
#      11
#      12             elif(choice == 2):
#
# KeyError: 0
